# %%
import numpy as np
import pandas as pd
import os, time, logging
from src.data import Hicmat, plot_data

# %%
hic_mat = Hicmat('./data/example/example.npy', 25000)

# %%
hic_mat.filter(threshold = 1)

# %%
plot_data(hic_mat.reduced_matrix)
# Out:
# d:\Programmation\Meet-EU - TeamSA1\src\data.py:51: RuntimeWarning: divide by zero encountered in log
#   m = np.log(m)
